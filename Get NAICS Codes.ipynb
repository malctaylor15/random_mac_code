# %% [markdown]
# ## Get all NAICS Codes

# %%
import sys
import os 
import pandas as pd 
import bs4
import requests
import datetime
import re
import urllib
import sqlite3
import time
from tqdm.notebook import tqdm

# %%
base_link = "https://www.naics.com/search/"

# %%
page = requests.get(base_link)

# %%
base_soup = bs4.BeautifulSoup(page.content, 'html.parser')

# %%
table = base_soup.find('table')
df = pd.read_html(str(table))[0]
df_base = df.copy()
df.head()
# Out:
#     Code                              Industry Title  \
# 0     11  Agriculture, Forestry, Fishing and Hunting
# 1     21                                      Mining
# 2     22                                   Utilities
# 3     23                                Construction
# 4  31-33                               Manufacturing
#
#    Number of Business Establishments
# 0                             378293
# 1                              32231
# 2                              44408
# 3                            1484279
# 4                             638730

# %% [raw]
# table_rows = table.find_all('tr')
# links = []
# for tr in table_rows:
#     td = tr.find_all('td')
#     rtd[0].find('a')['href']
#     l.append(row)

# %%
table_rows = table.find_all('tr')
links = []
for tr in table_rows:
    td = tr.find_all('td')
    try:
        temp_link = td[0].find('a')['href']
        links.append(temp_link)
    except:
        pass

# %%
links
# Out:
# ['https://www.naics.com/six-digit-naics/?code=11',
#  'https://www.naics.com/six-digit-naics/?code=21',
#  'https://www.naics.com/six-digit-naics/?code=22',
#  'https://www.naics.com/six-digit-naics/?code=23',
#  'https://www.naics.com/six-digit-naics/?code=31-33',
#  'https://www.naics.com/six-digit-naics/?code=42',
#  'https://www.naics.com/six-digit-naics/?code=44-45',
#  'https://www.naics.com/six-digit-naics/?code=48-49',
#  'https://www.naics.com/six-digit-naics/?code=51',
#  'https://www.naics.com/six-digit-naics/?code=52',
#  'https://www.naics.com/six-digit-naics/?code=53',
#  'https://www.naics.com/six-digit-naics/?code=54',
#  'https://www.naics.com/six-digit-naics/?code=55',
#  'https://www.naics.com/six-digit-naics/?code=56',
#  'https://www.naics.com/six-digit-naics/?code=61',
#  'https://www.naics.com/six-digit-naics/?code=62',
#  'https://www.naics.com/six-digit-naics/?code=71',
#  'https://www.naics.com/six-digit-naics/?code=72',
#  'https://www.naics.com/six-digit-naics/?code=81',
#  'https://www.naics.com/six-digit-naics/?code=92']

# %%
df_list = []
for link in links:
    page = requests.get(link)
    temp_soup = bs4.BeautifulSoup(page.content, 'html.parser')
    table = temp_soup.find('table')
    df = pd.read_html(str(table))[0]
    df_list.append(df)

# %%
len(df_list)
# Out:
# 20

# %%
all_naics_codes = pd.concat(df_list)
all_naics_codes['code_len'] = all_naics_codes['Codes'].apply(lambda x:len(str(x)))

# %%
all_naics_codes
# Out:
#      Codes                                       Titles  \
# 0       11   Agriculture, Forestry, Fishing and Hunting
# 1     1111                    Oilseed and Grain Farming
# 2   111110                              Soybean Farming
# 3   111120             Oilseed (except Soybean) Farming
# 4   111130                     Dry Pea and Bean Farming
# ..     ...                                          ...
# 33    9271                Space Research and Technology
# 34  927110                Space Research and Technology
# 35    9281  National Security and International Affairs
# 36  928110                            National Security
# 37  928120                        International Affairs
#
#     Total Marketable US Businesses  code_len
# 0                           378293         2
# 1                            61440         4
# 2                             4896         6
# 3                              208         6
# 4                             3666         6
# ..                             ...       ...
# 33                             138         4
# 34                             138         6
# 35                           17472         4
# 36                           15308         6
# 37                            2164         6
#
# [1388 rows x 4 columns]

# %%
all_naics_codes.to_csv('all_naics_codes.csv')

# %% [markdown]
# ## Extra....

# %%
def expand_df(row):
    row = row[1]
    split_code = row['Code'].split('-')
    temp_min = int(split_code[0])
    temp_max = int(split_code[1])
    numb_entries = temp_max - temp_min + 1

    series_list = []
    for x in range(temp_min, temp_max+1):
        series_dict = {'Code': x, 'Industry Title': row['Industry Title']
                       , "Number of Business Establishments":row['Number of Business Establishments']/numb_entries }
        series_list.append(series_dict)
    expanded_df = pd.DataFrame(series_list)
    
    return(expanded_df)

# %%
def clean_industry_table(df_raw):
    df = df_raw.copy()
    df = df.dropna()
    
    df.Code = df.Code.astype('str')
    code_with_hypen_mask = df.Code.str.contains('-')
    grouped_codes = df[code_with_hypen_mask]
    
    # Expand hypen columns
    expanded_dfs = []
    for row in grouped_codes.iterrows():
        expanded_dfs.append(expand_df(row))
    df_combo = pd.concat(expanded_dfs)
    
    # Remove hypen cols 
    df_no_hypen = df[~code_with_hypen_mask]
    df_w_expanded = pd.concat([df_no_hypen, df_combo])
    df_w_expanded['Code'] = df_w_expanded['Code']
    df_w_expanded['Code'] = df_w_expanded['Code'].astype('int')
    df_w_expanded = df_w_expanded.sort_values('Code')
    return(df_w_expanded)

# %%
cleaned_table = clean_industry_table(df_base)

# %%
cleaned_table
# Out:
#     Code                                     Industry Title  \
# 0     11         Agriculture, Forestry, Fishing and Hunting
# 1     21                                             Mining
# 2     22                                          Utilities
# 3     23                                       Construction
# 0     31                                      Manufacturing
# 1     32                                      Manufacturing
# 2     33                                      Manufacturing
# 5     42                                    Wholesale Trade
# 0     44                                       Retail Trade
# 1     45                                       Retail Trade
# 0     48                     Transportation and Warehousing
# 1     49                     Transportation and Warehousing
# 8     51                                        Information
# 9     52                              Finance and Insurance
# 10    53                     Real Estate Rental and Leasing
# 11    54   Professional, Scientific, and Technical Services
# 12    55            Management of Companies and Enterprises
# 13    56  Administrative and Support and Waste Managemen...
# 14    61                               Educational Services
# 15    62                  Health Care and Social Assistance
# 16    71                Arts, Entertainment, and Recreation
# 17    72                    Accommodation and Food Services
# 18    81      Other Services (except Public Administration)
# 19    92                              Public Administration
#
#     Number of Business Establishments
# 0                            378293.0
# 1                             32231.0
# 2                             44408.0
# 3                           1484279.0
# 0                            212910.0
# 1                            212910.0
# 2                            212910.0
# 5                            697579.0
# 0                            900083.0
# 1                            900083.0
# 0                            293630.5
# 1                            293630.5
# 8                            355030.0
# 9                            791029.0
# 10                           863427.0
# 11                          2196583.0
# 12                            71170.0
# 13                          1755832.0
# 14                           422162.0
# 15                          1683584.0
# 16                           363300.0
# 17                           901005.0
# 18                          1879818.0
# 19                           259799.0

# %%
df_alls.to_csv('naics2.csv')
